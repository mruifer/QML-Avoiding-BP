# %% [markdown]
# # ansatzs.py testing
#
# In this notebook we test the functions implemented in that file.
#
# In first place, we import the file.

# %%
import sys
sys.path.append('../')

from src import ansatzes as anz

# %% [markdown]
# ### Test of `build_deep_ansatz()` function:

# %%
# 4 qubits and 1 layers per qubit
circuit, num_params = anz.build_deep_ansatz(4, 1)
display(circuit.draw("mpl"))
# Out:
# c:\Users\juanl\miniconda3\envs\qiskit-tfm\Lib\site-packages\qiskit\visualization\circuit\matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %% [markdown]
# ### Test of `build_Nlocal_ansatz()` function:

# %%
# 8 qubits
circuit, num_params = anz.build_Nlocal_ansatz(8)
display(circuit.decompose().draw("mpl"))
# Out:
# c:\Users\juanl\miniconda3\envs\qiskit-tfm\Lib\site-packages\qiskit\visualization\circuit\matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %% [markdown]
# ### Test of `build_twoLocal_ansatz()` function:

# %%
# 6 qubits
circuit, num_params = anz.build_twoLocal_ansatz(6, 2)
display(circuit.decompose().draw("mpl"))

# %% [markdown]
# ### Test of `build_UCCSD_ansatz()` function:

# %%
# 5 qubits
circuit, num_params = anz.build_UCCSD_ansatz(5)
display(circuit.decompose().draw("mpl"))
# Out:
# c:\Users\juanl\miniconda3\envs\qiskit-tfm\Lib\site-packages\qiskit\visualization\circuit\matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %% [markdown]
# ### Test of `build_k_UCCSD_ansatz()` function:

# %%
# 3 qubits
circuit, num_params = anz.build_k_UCCSD_ansatz(4, 2)
display(circuit.decompose().draw("mpl"))
